# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 17904, done.
# remote: Counting objects: 100% (2702/2702), done.
# remote: Compressing objects: 100% (2153/2153), done.
# remote: Total 17904 (delta 842), reused 2301 (delta 507), pack-reused 15202 (from 1)
# Receiving objects: 100% (17904/17904), 26.21 MiB | 17.11 MiB/s, done.
# Resolving deltas: 100% (8584/8584), done.
# Updating files: 100% (9029/9029), done.

# %%
#pulse/data/aggregated/insurance
import os
path="/content/pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Insur=pd.DataFrame(clm)

# %%
Agg_Insur
# Out:
#                          State  Year  Quater Transacion_type  \
# 0    andaman-&-nicobar-islands  2022       4       Insurance
# 1    andaman-&-nicobar-islands  2022       2       Insurance
# 2    andaman-&-nicobar-islands  2022       1       Insurance
# 3    andaman-&-nicobar-islands  2022       3       Insurance
# 4    andaman-&-nicobar-islands  2023       4       Insurance
# ..                         ...   ...     ...             ...
# 677                    haryana  2020       3       Insurance
# 678                    haryana  2021       4       Insurance
# 679                    haryana  2021       2       Insurance
# 680                    haryana  2021       1       Insurance
# 681                    haryana  2021       3       Insurance
#
#      Transacion_count  Transacion_amount
# 0                 901          1441210.0
# 1                 501           779740.0
# 2                 768          1131287.0
# 3                 643           902466.0
# 4                1145          1757821.0
# ..                ...                ...
# 677              7139          1884868.0
# 678             19489         25885838.0
# 679             12516         11272453.0
# 680             11038          7297880.0
# 681             14163         13215898.0
#
# [682 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Agg_Insur.to_csv("Agg_Insur.csv", index=False)

print("CSV file 'Agg_Insur.csv' saved successfully!")
# Out:
# CSV file 'Agg_Insur.csv' saved successfully!

# %%
#pulse/data/aggregated/transaction
import os
path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#              State  Year  Quater           Transacion_type  Transacion_count  \
# 0        jharkhand  2021       1     Peer-to-peer payments          19151083
# 1        jharkhand  2021       1         Merchant payments          17489113
# 2        jharkhand  2021       1  Recharge & bill payments           7826608
# 3        jharkhand  2021       1        Financial Services             50526
# 4        jharkhand  2021       1                    Others            104333
# ...            ...   ...     ...                       ...               ...
# 5029  chhattisgarh  2024       3         Merchant payments         267508081
# 5030  chhattisgarh  2024       3     Peer-to-peer payments         146302685
# 5031  chhattisgarh  2024       3  Recharge & bill payments          29502494
# 5032  chhattisgarh  2024       3        Financial Services            179562
# 5033  chhattisgarh  2024       3                    Others            147280
#
#       Transacion_amount
# 0          6.919824e+10
# 1          1.154558e+10
# 2          2.888410e+09
# 3          5.483661e+07
# 4          6.229034e+07
# ...                 ...
# 5029       1.364190e+11
# 5030       3.422361e+11
# 5031       1.822658e+10
# 5032       3.540200e+08
# 5033       1.244158e+08
#
# [5034 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Agg_Trans.to_csv("Agg_Trans.csv", index=False)

print("CSV file 'Agg_Trans.csv' saved successfully!")
# Out:
# CSV file 'Agg_Trans.csv' saved successfully!

# %%
#pulse/data/aggregated/user
import os
path="/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
import pandas as pd
import json
import os

# Define the path to the data directory
path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)

# Dictionary to store extracted data
clm = {'State': [], 'Year': [], 'Quarter': [], 'Brand': [], 'Registered_Users': [], 'App_Opens': [], 'Total_Registered_Users': [], 'Total_App_Opens': []}

# Extracting data to create a dataframe
for i in Agg_state_list:
    p_i = path + i + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                total_registered_users = D['data']['aggregated']['registeredUsers']
                total_app_opens = D['data']['aggregated']['appOpens']

                if 'usersByDevice' in D['data'] and D['data']['usersByDevice'] is not None:
                    for z in D['data']['usersByDevice']:
                        clm['Brand'].append(z['brand'])
                        clm['Registered_Users'].append(z['count'])
                        clm['App_Opens'].append(total_app_opens)
                        clm['State'].append(i)
                        clm['Year'].append(j)
                        clm['Quarter'].append(int(k.strip('.json')))
                        clm['Total_Registered_Users'].append(total_registered_users)
                        clm['Total_App_Opens'].append(total_app_opens)

# Successfully created a dataframe
Agg_Users = pd.DataFrame(clm)

# %%
Agg_Users
# Out:
#              State  Year  Quarter     Brand  Registered_Users  App_Opens  \
# 0        jharkhand  2021        1    Xiaomi           1499838  141731331
# 1        jharkhand  2021        1   Samsung            957520  141731331
# 2        jharkhand  2021        1      Vivo            914415  141731331
# 3        jharkhand  2021        1      Oppo            671681  141731331
# 4        jharkhand  2021        1    Realme            479676  141731331
# ...            ...   ...      ...       ...               ...        ...
# 6727  chhattisgarh  2018        3   OnePlus             23810          0
# 6728  chhattisgarh  2018        3     Apple             23566          0
# 6729  chhattisgarh  2018        3  Motorola             19369          0
# 6730  chhattisgarh  2018        3    Lenovo             18890          0
# 6731  chhattisgarh  2018        3    Others            121702          0
#
#       Total_Registered_Users  Total_App_Opens
# 0                    5313049        141731331
# 1                    5313049        141731331
# 2                    5313049        141731331
# 3                    5313049        141731331
# 4                    5313049        141731331
# ...                      ...              ...
# 6727                 1217792                0
# 6728                 1217792                0
# 6729                 1217792                0
# 6730                 1217792                0
# 6731                 1217792                0
#
# [6732 rows x 8 columns]

# %%
import json
import os
import pandas as pd

# This is to extract the data and create a DataFrame
path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)  # List of states in India

clm = {'State': [], 'Year': [], 'Quater': [], 'User_Brand': [], 'User_Count': [], 'User_Percentage': []}

for i in Agg_state_list:
    state_path = os.path.join(path, i)
    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)
        for quarter_file in os.listdir(year_path):
            file_path = os.path.join(year_path, quarter_file)
            try:
                with open(file_path, 'r') as Data:
                    D = json.load(Data)
                    users_by_device = D.get('data', {}).get('usersByDevice', [])

                    if users_by_device:
                        for device in users_by_device:
                            clm['State'].append(i)
                            clm['Year'].append(year)
                            clm['Quater'].append(int(quarter_file.replace('.json', '')))
                            clm['User_Brand'].append(device.get('brand', 'Unknown'))
                            clm['User_Count'].append(device.get('count', 0))
                            clm['User_Percentage'].append(device.get('percentage', 0.0))

            except (KeyError, json.JSONDecodeError, TypeError) as e:
                print(f"Error processing file {file_path}: {e}")
                clm['State'].append(i)
                clm['Year'].append(year)
                clm['Quater'].append(int(quarter_file.replace('.json', '')))
                clm['User_Brand'].append(None)
                clm['User_Count'].append(0)
                clm['User_Percentage'].append(0.0)

# Successfully created a DataFrame
Agg_Users = pd.DataFrame(clm)

# %%
Agg_Users
# Out:
#              State  Year  Quater User_Brand  User_Count  User_Percentage
# 0        jharkhand  2021       1     Xiaomi     1499838         0.282293
# 1        jharkhand  2021       1    Samsung      957520         0.180220
# 2        jharkhand  2021       1       Vivo      914415         0.172107
# 3        jharkhand  2021       1       Oppo      671681         0.126421
# 4        jharkhand  2021       1     Realme      479676         0.090283
# ...            ...   ...     ...        ...         ...              ...
# 6727  chhattisgarh  2018       3    OnePlus       23810         0.019552
# 6728  chhattisgarh  2018       3      Apple       23566         0.019351
# 6729  chhattisgarh  2018       3   Motorola       19369         0.015905
# 6730  chhattisgarh  2018       3     Lenovo       18890         0.015512
# 6731  chhattisgarh  2018       3     Others      121702         0.099937
#
# [6732 rows x 6 columns]

# %%
import os
import json
import pandas as pd

# Define the path to the data directory
path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)

# Dictionary to store extracted data
clm = {
    'State': [], 'Year': [], 'Quarter': [], 'Brand': [], 'Registered_Users': [], 'App_Opens': [],
    'Total_Registered_Users': [], 'Total_App_Opens': [], 'User_Percentage': []
}

# Extracting data to create a dataframe
for state in Agg_state_list:
    state_path = os.path.join(path, state)
    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)
        for quarter_file in os.listdir(year_path):
            file_path = os.path.join(year_path, quarter_file)
            try:
                with open(file_path, 'r') as Data:
                    D = json.load(Data)
                    total_registered_users = D.get('data', {}).get('aggregated', {}).get('registeredUsers', 0)
                    total_app_opens = D.get('data', {}).get('aggregated', {}).get('appOpens', 0)
                    users_by_device = D.get('data', {}).get('usersByDevice', [])

                    if users_by_device:
                        for device in users_by_device:
                            clm['State'].append(state)
                            clm['Year'].append(year)
                            clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                            clm['Brand'].append(device.get('brand', 'Unknown'))
                            clm['Registered_Users'].append(device.get('count', 0))
                            clm['App_Opens'].append(total_app_opens)
                            clm['Total_Registered_Users'].append(total_registered_users)
                            clm['Total_App_Opens'].append(total_app_opens)
                            clm['User_Percentage'].append(device.get('percentage', 0.0))
                    else:
                        clm['State'].append(state)
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                        clm['Brand'].append(None)
                        clm['Registered_Users'].append(0)
                        clm['App_Opens'].append(0)
                        clm['Total_Registered_Users'].append(0)
                        clm['Total_App_Opens'].append(0)
                        clm['User_Percentage'].append(0.0)
            except (KeyError, json.JSONDecodeError, TypeError) as e:
                print(f"Error processing file {file_path}: {e}")
                clm['State'].append(state)
                clm['Year'].append(year)
                clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                clm['Brand'].append(None)
                clm['Registered_Users'].append(0)
                clm['App_Opens'].append(0)
                clm['Total_Registered_Users'].append(0)
                clm['Total_App_Opens'].append(0)
                clm['User_Percentage'].append(0.0)

# Successfully created a DataFrame
Agg_Users = pd.DataFrame(clm)
print(Agg_Users.head())
# Out:
#        State  Year  Quarter    Brand  Registered_Users  App_Opens  \
# 0  jharkhand  2021        1   Xiaomi           1499838  141731331
# 1  jharkhand  2021        1  Samsung            957520  141731331
# 2  jharkhand  2021        1     Vivo            914415  141731331
# 3  jharkhand  2021        1     Oppo            671681  141731331
# 4  jharkhand  2021        1   Realme            479676  141731331
#
#    Total_Registered_Users  Total_App_Opens  User_Percentage
# 0                 5313049        141731331         0.282293
# 1                 5313049        141731331         0.180220
# 2                 5313049        141731331         0.172107
# 3                 5313049        141731331         0.126421
# 4                 5313049        141731331         0.090283

# %%
# Save the DataFrame as a CSV file
Agg_Users.to_csv("Agg_Users.csv", index=False)

print("CSV file 'Agg_Users.csv' saved successfully!")
# Out:
# CSV file 'Agg_Users.csv' saved successfully!

# %%
#pulse/data/map/insurance
import os
path="/content/pulse/data/map/insurance/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/map/insurance/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
#map_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Insurance_type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in map_state_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Insurance_type'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Insur=pd.DataFrame(clm)

# %%
Map_Insur
# Out:
#               State  Year  Quater                Insurance_type  \
# 0         jharkhand  2021       1              ramgarh district
# 1         jharkhand  2021       1               ranchi district
# 2         jharkhand  2021       1       east singhbhum district
# 3         jharkhand  2021       1              jamtara district
# 4         jharkhand  2021       1                dumka district
# ...             ...   ...     ...                           ...
# 13871  chhattisgarh  2024       3  north bastar kanker district
# 13872  chhattisgarh  2024       3  sarangarh bilaigarh district
# 13873  chhattisgarh  2024       3               bastar district
# 13874  chhattisgarh  2024       3            kondagaon district
# 13875  chhattisgarh  2024       3           mahasamund district
#
#        Insurance_count  Insurance_amount
# 0                  204          131405.0
# 1                 1026          734770.0
# 2                  625          404402.0
# 3                   38           18540.0
# 4                   80           49753.0
# ...                ...               ...
# 13871              323          656134.0
# 13872              178          302602.0
# 13873              634         1101607.0
# 13874              189          376719.0
# 13875              321          521649.0
#
# [13876 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Map_Insur.to_csv("Map_Insur.csv", index=False)

print("CSV file 'Map_Insur.csv' saved successfully!")
# Out:
# CSV file 'Map_Insur.csv' saved successfully!

# %%
#pulse/data/map/transaction
import os
path="/content/pulse/data/map/transaction/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/map/transaction/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
#map_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in map_state_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Trans=pd.DataFrame(clm)

# %%
Map_Trans
# Out:
#               State  Year  Quater              Transaction_type  \
# 0         jharkhand  2021       1              ramgarh district
# 1         jharkhand  2021       1               ranchi district
# 2         jharkhand  2021       1       east singhbhum district
# 3         jharkhand  2021       1              jamtara district
# 4         jharkhand  2021       1                dumka district
# ...             ...   ...     ...                           ...
# 20599  chhattisgarh  2024       3  north bastar kanker district
# 20600  chhattisgarh  2024       3  sarangarh bilaigarh district
# 20601  chhattisgarh  2024       3               bastar district
# 20602  chhattisgarh  2024       3            kondagaon district
# 20603  chhattisgarh  2024       3           mahasamund district
#
#        Transaction_count  Transaction_amount
# 0                1838015        3.113016e+09
# 1               11611641        2.051652e+10
# 2                4431654        6.647300e+09
# 3                 208526        4.568389e+08
# 4                 485116        1.054598e+09
# ...                  ...                 ...
# 20599            7960785        1.028559e+10
# 20600            7437919        8.890114e+09
# 20601           12581699        1.430788e+10
# 20602            4958450        6.162637e+09
# 20603           13361028        1.668049e+10
#
# [20604 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Map_Trans.to_csv("Map_Trans.csv", index=False)

print("CSV file 'Map_Trans.csv' saved successfully!")
# Out:
# CSV file 'Map_Trans.csv' saved successfully!

# %%
#pulse/data/map/user
import os
path="/content/pulse/data/map/user/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
import pandas as pd
import json
import os

# This is to direct the path to get the data as states
path = "/content/pulse/data/map/user/hover/country/india/state/"
map_state_list = os.listdir(path)  # List of states in India

# Extracting data to create a DataFrame
clm = {'State': [], 'Year': [], 'Quater': [], 'Registered_Users': [], 'App_Opens': []}

for i in map_state_list:
    state_path = os.path.join(path, i)
    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)
        for quarter_file in os.listdir(year_path):
            file_path = os.path.join(year_path, quarter_file)
            try:
                with open(file_path, 'r') as Data:
                    D = json.load(Data)
                    hover_data = D.get('data', {}).get('hoverData', {})

                    for location, details in hover_data.items():
                        clm['State'].append(i)
                        clm['Year'].append(year)
                        clm['Quater'].append(int(quarter_file.replace('.json', '')))
                        clm['Registered_Users'].append(details.get('registeredUsers', 0))
                        clm['App_Opens'].append(details.get('appOpens', 0))

            except (KeyError, json.JSONDecodeError, TypeError) as e:
                print(f"Error processing file {file_path}: {e}")
                clm['State'].append(i)
                clm['Year'].append(year)
                clm['Quater'].append(int(quarter_file.replace('.json', '')))
                clm['Registered_Users'].append(0)
                clm['App_Opens'].append(0)

# Successfully created a DataFrame
Map_Users = pd.DataFrame(clm)

# %%
Map_Users
# Out:
#               State  Year  Quater  Registered_Users  App_Opens
# 0         jharkhand  2021       1            216188    6534314
# 1         jharkhand  2021       1            853943   24364256
# 2         jharkhand  2021       1            560083   13862208
# 3         jharkhand  2021       1             97127    1055011
# 4         jharkhand  2021       1            106316    2134734
# ...             ...   ...     ...               ...        ...
# 20603  chhattisgarh  2024       3            241602   86000519
# 20604  chhattisgarh  2024       3            201039   18608126
# 20605  chhattisgarh  2024       3            275288   74884408
# 20606  chhattisgarh  2024       3            155624   66461484
# 20607  chhattisgarh  2024       3            348919   46837825
#
# [20608 rows x 5 columns]

# %%
# Save the DataFrame as a CSV file
Map_Users.to_csv("Map_Users.csv", index=False)

print("CSV file 'Map_Users.csv' saved successfully!")
# Out:
# CSV file 'Map_Users.csv' saved successfully!

# %%
#pulse/data/top/insurance
import os
path="/content/pulse/data/top/insurance/country/india/state/"
top_state_list=os.listdir(path)
top_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
import pandas as pd
import json
import os

# Path to the data
path = "/content/pulse/data/top/insurance/country/india/"

# Initialize DataFrame structure
clm = {'State/District/Pincode': [], 'Year': [], 'Quater': [], 'Category': [], 'Insurance_count': [], 'Insurance_amount': []}

# Loop through the available years
for year in os.listdir(path):
    year_path = os.path.join(path, year)

    # Check if it's a valid directory
    if not os.path.isdir(year_path):
        continue

    # Loop through all JSON files directly inside the Year folder
    for file in os.listdir(year_path):
        if file.endswith(".json"):
            file_path = os.path.join(year_path, file)

            with open(file_path, 'r') as Data:
                D = json.load(Data)

            # Extract state/district/pincode level data
            for category in ["states", "districts", "pincodes"]:
                if category in D["data"]:
                    for entry in D["data"][category]:
                        clm['State/District/Pincode'].append(entry["entityName"])
                        clm['Year'].append(year)
                        clm['Quater'].append(int(file.strip('.json')))  # Extract quarter from filename
                        clm['Category'].append(category)
                        clm['Insurance_count'].append(entry["metric"]["count"])
                        clm['Insurance_amount'].append(entry["metric"]["amount"])

# Convert to DataFrame
Top_Insur = pd.DataFrame(clm)

# %%
Top_Insur
# Out:
#     State/District/Pincode  Year  Quater  Category  Insurance_count  \
# 0              maharashtra  2021       1    states            55792
# 1                karnataka  2021       1    states            37595
# 2                telangana  2021       1    states            28298
# 3            uttar pradesh  2021       1    states            24103
# 4           andhra pradesh  2021       1    states            22105
# ..                     ...   ...     ...       ...              ...
# 565                 201301  2024       3  pincodes             2329
# 566                 500072  2024       3  pincodes             2327
# 567                 560091  2024       3  pincodes             2326
# 568                 122001  2024       3  pincodes             2270
# 569                 560103  2024       3  pincodes             2228
#
#      Insurance_amount
# 0          33137753.0
# 1          30183325.0
# 2          14810947.0
# 3          18027573.0
# 4          12749874.0
# ..                ...
# 565         3345795.0
# 566         3766931.0
# 567         3714785.0
# 568         3090606.0
# 569         3764086.0
#
# [570 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Top_Insur.to_csv("Top_Insur.csv", index=False)

print("CSV file 'Top_Insur.csv' saved successfully!")
# Out:
# CSV file 'Top_Insur.csv' saved successfully!

# %%
#pulse/data/top/transaction
import os
path="/content/pulse/data/top/transaction/country/india/state/"
top_state_list=os.listdir(path)
top_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
import pandas as pd
import json
import os

# Path to the data
path = "/content/pulse/data/top/transaction/country/india/"

# Initialize DataFrame structure
clm = {'State/District/Pincode': [], 'Year': [], 'Quater': [], 'Category': [], 'Transaction_count': [], 'Transaction_amount': []}

# Loop through the available years
for year in os.listdir(path):
    year_path = os.path.join(path, year)

    # Check if it's a valid directory
    if not os.path.isdir(year_path):
        continue

    # Loop through all JSON files directly inside the Year folder
    for file in os.listdir(year_path):
        if file.endswith(".json"):
            file_path = os.path.join(year_path, file)

            with open(file_path, 'r') as Data:
                D = json.load(Data)

            # Extract state/district/pincode level data
            for category in ["states", "districts", "pincodes"]:
                if category in D["data"]:
                    for entry in D["data"][category]:
                        clm['State/District/Pincode'].append(entry["entityName"])
                        clm['Year'].append(year)
                        clm['Quater'].append(int(file.strip('.json')))  # Extract quarter from filename
                        clm['Category'].append(category)
                        clm['Transaction_count'].append(entry["metric"]["count"])
                        clm['Transaction_amount'].append(entry["metric"]["amount"])

# Convert to DataFrame
Top_Trans = pd.DataFrame(clm)

# %%
Top_Trans
# Out:
#     State/District/Pincode  Year  Quater  Category  Transaction_count  \
# 0                karnataka  2021       1    states          523797492
# 1              maharashtra  2021       1    states          517860240
# 2                telangana  2021       1    states          412572110
# 3           andhra pradesh  2021       1    states          289747970
# 4                rajasthan  2021       1    states          252730919
# ..                     ...   ...     ...       ...                ...
# 835                 452001  2024       3  pincodes           54979662
# 836                 410501  2024       3  pincodes           51594896
# 837                 560037  2024       3  pincodes           50010832
# 838                 411057  2024       3  pincodes           46700269
# 839                 560066  2024       3  pincodes           44823424
#
#      Transaction_amount
# 0          7.549954e+11
# 1          7.698874e+11
# 2          7.993593e+11
# 3          6.724447e+11
# 4          4.914926e+11
# ..                  ...
# 835        4.897731e+10
# 836        3.848434e+10
# 837        5.199562e+10
# 838        3.762870e+10
# 839        4.568157e+10
#
# [840 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Top_Trans.to_csv("Top_Trans.csv", index=False)

print("CSV file 'Top_Trans.csv' saved successfully!")
# Out:
# CSV file 'Top_Trans.csv' saved successfully!

# %%
#pulse/data/top/user
import os
path="/content/pulse/data/top/user/country/india/state/"
top_state_list=os.listdir(path)
top_state_list
# Out:
# ['jharkhand',
#  'west-bengal',
#  'uttarakhand',
#  'uttar-pradesh',
#  'andhra-pradesh',
#  'odisha',
#  'andaman-&-nicobar-islands',
#  'lakshadweep',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'karnataka',
#  'meghalaya',
#  'ladakh',
#  'sikkim',
#  'telangana',
#  'goa',
#  'jammu-&-kashmir',
#  'tripura',
#  'assam',
#  'arunachal-pradesh',
#  'delhi',
#  'kerala',
#  'himachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'chandigarh',
#  'rajasthan',
#  'madhya-pradesh',
#  'nagaland',
#  'bihar',
#  'gujarat',
#  'maharashtra',
#  'manipur',
#  'puducherry',
#  'haryana',
#  'punjab',
#  'chhattisgarh']

# %%
import pandas as pd
import json
import os

# Define the path to user registration data
path = "/content/pulse/data/top/user/country/india/state/"
user_state_list = os.listdir(path)

# Dictionary to store extracted data
clm = {'State/District/Pincode': [], 'Year': [], 'Quarter': [], 'Registered_Users': []}

for state in user_state_list:
    state_path = os.path.join(path, state)
    years = os.listdir(state_path)

    for year in years:
        year_path = os.path.join(state_path, year)
        quarters = os.listdir(year_path)

        for quarter in quarters:
            quarter_path = os.path.join(year_path, quarter)

            # Read JSON file
            with open(quarter_path, 'r') as data_file:
                D = json.load(data_file)

            # Ensure 'data' exists before accessing its keys
            if 'data' in D and D['data']:

                # Process state-level data
                if 'states' in D['data'] and D['data']['states']:
                    for state_data in D['data']['states']:
                        clm['State/District/Pincode'].append(state_data.get('name', 'Unknown'))
                        clm['Registered_Users'].append(state_data.get('registeredUsers', 0))
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter.strip('.json')))

                # Process district-level data
                if 'districts' in D['data'] and D['data']['districts']:
                    for district_data in D['data']['districts']:
                        clm['State/District/Pincode'].append(district_data.get('name', 'Unknown'))
                        clm['Registered_Users'].append(district_data.get('registeredUsers', 0))
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter.strip('.json')))

                # Process pincode-level data
                if 'pincodes' in D['data'] and D['data']['pincodes']:
                    for pincode_data in D['data']['pincodes']:
                        clm['State/District/Pincode'].append(pincode_data.get('name', 'Unknown'))
                        clm['Registered_Users'].append(pincode_data.get('registeredUsers', 0))
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter.strip('.json')))

# Convert dictionary to DataFrame
Top_Users = pd.DataFrame(clm)

# %%
Top_Users
# Out:
#       State/District/Pincode  Year  Quarter  Registered_Users
# 0                     ranchi  2021        1            853943
# 1                    dhanbad  2021        1            661077
# 2             east singhbhum  2021        1            560083
# 3                     bokaro  2021        1            480036
# 4                 hazaribagh  2021        1            366460
# ...                      ...   ...      ...               ...
# 18291                 491441  2024        3            176824
# 18292                 493221  2024        3            167870
# 18293                 494001  2024        3            156652
# 18294                 492099  2024        3            130619
# 18295                 491995  2024        3            125067
#
# [18296 rows x 4 columns]

# %%
# Save the DataFrame as a CSV file
Top_Users.to_csv("Top_Users.csv", index=False)

print("CSV file 'Top_Users.csv' saved successfully!")
# Out:
# CSV file 'Top_Users.csv' saved successfully!
